# %%
# Let's store a string (string = any kind of text) in a variable.

dummy = "Hello world!"
print(dummy)
# Out:
# Hello world!

# %%
# Let's check the data type of variable 'dummy'

print(type(dummy))
# Out:
# <class 'str'>

# %%
num=5
another_num=8.6
print(type(num))
print(type(another_num))
# Out:
# <class 'int'>
# <class 'float'>

# %%
val = True
print(type(val))
# Out:
# <class 'bool'>

# %%
print(num)
print(another_num)
print(val)
# Out:
# 5
# 8.6
# True

# %%
test = 'Python is high-level,interpreted programming language'
print(test)
# Out:
# Python is high-level,interpreted programming language

# %%
test = "Python is high-level,interpreted programming language"
print(test)
# Out:
# Python is high-level,interpreted programming language

# %%
text = "Hello World!"
print(len(text))
# Out:
# 12

# %%
text = "PLANET EARTH"
print(text[0])
print(text[4])
# Out:
# P
# E

# %%
print(text[2:5])
print(text[:2])
print(text[-2:])
print(text[2:])
# Out:
# ANE
# PL
# TH
# ANET EARTH

# %%
text = "Welcome to Python!"
print(type(text))
print(type(text[2:4]))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(text.upper())
# Out:
# WELCOME TO PYTHON!

# %%
print(text.lower())
# Out:
# welcome to python!

# %%
print(text.title())
# Out:
# Welcome To Python!

# %%
text ='hello planet'
print(text.count('1'))
# Out:
# 0

# %%
print(text.count('et'))
# Out:
# 1

# %%
print(text.find('o'))
# Out:
# 4

# %%
print(text.find('Z'))
# Out:
# -1

# %%
print(text)
print(text.count('H'))
# Out:
# hello planet
# 0

# %%
print(text.find('H'))
# Out:
# -1

# %%
text = "Welcome to this beautiful place"
print(text.find('beautiful'))
# Out:
# 16

# %%
print(text.count('beautiful'))
print(text.count('is'))
# Out:
# 1
# 1

# %%
print(text.replace('place','planet'))
# Out:
# Welcome to this beautiful planet

# %%
print(text)
# Out:
# Welcome to this beautiful place

# %%
new_text = text.replace('place','planet')
print(new_text)
print(text)
# Out:
# Welcome to this beautiful planet
# Welcome to this beautiful place

# %%
fruit = "Cherrrryyy"
print(fruit.replace('r','R'))
print(fruit.replace('C','c'))
# Out:
# CheRRRRyyy
# cherrrryyy

# %%
msg = ' Hello World   '
print(msg)
print(msg.strip())
# Out:
#  Hello World
# Hello World

# %%
print(len(msg))
# Out:
# 15

# %%
print(len(msg.strip()))
# Out:
# 11

# %%
print(msg.count(' '))
print(msg.strip().count(' '))
# Out:
# 5
# 1

# %%
address = '102,Baker Street,London'
print(address.split(','))
# Out:
# ['102', 'Baker Street', 'London']

# %%
address = '102,PUNE'
print(address.split(','))
# Out:
# ['102', 'PUNE']

# %%
test = "Whatsup! How you doing"
print(test.split(' '))
# Out:
# ['Whatsup!', 'How', 'you', 'doing']

# %%
output = test.split(' ')
print(output)
print(type(output))
# Out:
# ['Whatsup!', 'How', 'you', 'doing']
# <class 'list'>

# %%
first_name = 'Mark'
last_name = 'Zuckerberg'
name = first_name + last_name
print(first_name  +  last_name)
# Out:
# MarkZuckerberg

# %%
first = 'Mark'
second = 'Zuckerberg'
name = first + second
print(first+' '+second)
# Out:
# Mark Zuckerberg

# %%
print(name)
# Out:
# MarkZuckerberg

# %%
name='{}{}'.format(first,second)
print(name)
# Out:
# MarkZuckerberg

# %%
name = '{} {}'.format(first,second)
print(name)

name = '  {}   {}   '.format(first,second)
print(name)

name =' {}  {}'.format(second,first)
print(name)
# Out:
# Mark Zuckerberg
#   Mark   Zuckerberg
#  Zuckerberg  Mark

# %%
name =f'{first}{second}'
print(name)
# Out:
# MarkZuckerberg

# %%
name=f'{first} {second}'
print(name)

name = f'{first}    {second}'
print(name)
# Out:
# Mark Zuckerberg
# Mark    Zuckerberg

# %%
name = f'{first.upper()}  {second.lower()}'
print(name)
# Out:
# MARK  zuckerberg

# %%
#INTEGER & FLOAT
num1=4
num2=8
print(num1,num2)
print(type(num1),type(num2))
# Out:
# 4 8
# <class 'int'> <class 'int'>

# %%
add = num1 + num2
print(add)
# Out:
# 12

# %%
print(num1+num2)
print(num1-num2)
print(num1/num2)
print(num1//num2)
print(num1*num2)
print(num1%num2)
# Out:
# 12
# -4
# 0.5
# 0
# 32
# 4

# %%
print(type(num2/num1))
# Out:
# <class 'float'>

# %%
new_num1 = 3.5
new_num2 = 5.5
print(new_num1+new_num2)
# Out:
# 9.0

# %%
print(new_num1-new_num2)
# Out:
# -2.0

# %%
print(new_num1+new_num2)
print(new_num1-new_num2)
print(new_num1/new_num2)
print(new_num1//new_num2)
print(new_num1*new_num2)
print(new_num1%new_num2)
# Out:
# 9.0
# -2.0
# 0.6363636363636364
# 0.0
# 19.25
# 3.5

# %%
print(num2-new_num2)
# Out:
# 2.5

# %%
print(num2-new_num2)
# Out:
# 2.5

# %%
fir = 7
sec = 0.1
print(fir + sec)
# Out:
# 7.1

# %%
#Accepting User Input
name = input('Enter Your Name:')
print(name)
print(type(name))
# Out:
# Enter Your Name:Gunjan
# Gunjan
# <class 'str'>

# %%
name = input('Enter something')
print(name)
print(type(name))
# Out:
# Enter somethingabc
# abc
# <class 'str'>

# %%
text = input('Enter Something :')
print(text.upper())
print(text.lower())
print(text.title())
print(text.find('e'))
print(text.count('e'))
print(text.replace('s','z'))
print(len(text))
# Out:
# Enter Something :Mango is the fruit
# MANGO IS THE FRUIT
# mango is the fruit
# Mango Is The Fruit
# 11
# 1
# Mango iz the fruit
# 18

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
# ?str.title

# %%
help(str.upper)
# Out:
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.

# %%
help(str.title)
# Out:
# Help on method_descriptor:
#
# title(self, /) unbound builtins.str method
#     Return a version of the string where each word is titlecased.
#
#     More specifically, words start with uppercased characters and all remaining
#     cased characters have lower case.

# %%
help(str.lower)
# Out:
# Help on method_descriptor:
#
# lower(self, /) unbound builtins.str method
#     Return a copy of the string converted to lowercase.

# %%
# ?str.upper()
# Out:
# Object `str.upper()` not found.
