# %%
myset = {"apple", "banana", "cherry"}
print(myset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
myset = {"apple", "banana", "cherry","True",1}
print(myset)
# Out:
# {1, 'banana', 'True', 'cherry', 'apple'}

# %%
thisset = {"apple","banana","cherry","litchi","grapes"}
for x in thisset:
  print(x)
# Out:
# banana
# grapes
# cherry
# apple
# litchi

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}

print("banana" in thisset)
# Out:
# True

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
print("banana" not in thisset)
# Out:
# False

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
thisset.add("orange")

print(thisset)
# Out:
# {'banana', 'orange', 'grapes', 'cherry', 'apple', 'litchi'}

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'mango', 'banana', 'pineapple', 'papaya', 'grapes', 'cherry', 'apple', 'litchi'}

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'banana', 'cherry', 'kiwi', 'apple', 'orange'}

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}


thisset.remove("banana")

print(thisset)
# Out:
# {'grapes', 'cherry', 'apple', 'litchi'}

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
thisset.discard("cherry")

print(thisset)
# Out:
# {'banana', 'grapes', 'apple', 'litchi'}

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
x = thisset.pop()

print(x)

print(thisset)
# Out:
# banana
# {'grapes', 'cherry', 'apple', 'litchi'}

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
del thisset
print(thisset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2157/209392257.py in <cell line: 0>()
#       1 thisset = {"apple", "banana", "cherry","litchi","grapes"}
#       2 del thisset
# ----> 3 print(thisset)
#
# NameError: name 'thisset' is not defined

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}

thisset.clear()

print(thisset)
# Out:
# set()

# %%
thisset = {"apple", "banana", "cherry","litchi","grapes"}
for x in thisset:
  print(x)
# Out:
# banana
# grapes
# cherry
# apple
# litchi

# %%
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'cherry', 'banana', 'apple'})
# <class 'frozenset'>

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {'a', 1, 2, 3, 'b', 'c'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1 | set2
print(set3)
# Out:
# {'a', 1, 2, 3, 'b', 'c'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Dave","Eva"}
set4 = {"apple", "banana", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {'a', 1, 2, 3, 'banana', 'b', 'cherry', 'c', 'Eva', 'John', 'apple', 'Dave'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1 | set2 | set3 |set4
print(myset)
# Out:
# {'a', 1, 2, 3, 'bananas', 'b', 'cherry', 'c', 'apple', 'John', 'Elena'}

# %%
x = {"a", "B", "c"}
y = (1, 2, 3)

z = x.union(y)
print(z)
# Out:
# {'a', 2, 1, 3, 'B', 'c'}

# %%
set1 = {"A", "B" , "C"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)
# Out:
# {'A', 1, 2, 3, 'B', 'C'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)
# Out:
# {'apple'}

# %%
#sets that contains the values True, False, 1, and 0, and see what is considered as duplicates:

set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}

set3 = set1.intersection(set2)

print(set3)
# Out:
# {False, 1, 'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 - set2
print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)

print(set1)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)
# Out:
# {'banana', 'cherry', 'microsoft', 'google'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'banana', 'cherry', 'microsoft', 'google'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)
# Out:
# {'banana', 'cherry', 'microsoft', 'google'}

# %%
set1 = {"apple", "banana", "cherry"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2157/3814284697.py in <cell line: 0>()
#       1 set1 = {"apple", "banana", "cherry"}
#       2 set2 = {"google", "microsoft", "apple"}
# ----> 3 print.copy(set1)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'copy'

# %%
set1 = {"apple","Banana","Cherry"}
set2 = {"google","microsoft","apple"}
set_copy = set1.copy()
print(set_copy)
# Out:
# {'Cherry', 'Banana', 'apple'}

# %%
set1 = {"apple","Banana","Cherry"}
set2 = {"google","microsoft","apple"}
set_copy = set2.copy()
print(set_copy)
# Out:
# {'microsoft', 'google', 'apple'}
